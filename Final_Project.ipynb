# %% [markdown]
# Final Project.

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
avail = pd.read_csv("availabilities.csv")
host = pd.read_csv("hosts.csv")
# lst = pd.read_csv("listings.csv")
rev = pd.read_csv("reviews.csv")

# %%
# Had to strip the first line from the file - just a title line, then worked fine.
lst = pd.read_csv('listings.csv')

# %%
avail
# Out:
#          listing_id      date available     price  minimum_nights  \
# 0              2384  11/21/19         t   $65.00                2
# 1              2384  11/22/19         f   $65.00                2
# 2              2384  11/23/19         f   $65.00                2
# 3              2384  11/24/19         f   $65.00                2
# 4              2384  11/25/19         f   $65.00                2
# ...             ...       ...       ...       ...             ...
# 1048570    21788299    7/8/20         f  $239.00                2
# 1048571    21788299    7/9/20         f  $239.00                2
# 1048572    21788299   7/10/20         f  $239.00                2
# 1048573    21788299   7/11/20         f  $239.00                2
# 1048574    21788299   7/12/20         f  $239.00                2
#
#          maximum_nights
# 0                  1125
# 1                  1125
# 2                  1125
# 3                  1125
# 4                  1125
# ...                 ...
# 1048570            1125
# 1048571            1125
# 1048572            1125
# 1048573            1125
# 1048574            1125
#
# [1048575 rows x 6 columns]

# %%
avail.isnull()
avail.isna().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
host
# Out:
#              id                                     host_url  \
# 0          2613       https://www.airbnb.com/users/show/2613
# 1          5775       https://www.airbnb.com/users/show/5775
# 2         17928      https://www.airbnb.com/users/show/17928
# 3         33004      https://www.airbnb.com/users/show/33004
# 4          2140       https://www.airbnb.com/users/show/2140
# ...         ...                                          ...
# 4622  285121807  https://www.airbnb.com/users/show/285121807
# 4623   50982462   https://www.airbnb.com/users/show/50982462
# 4624  114503989  https://www.airbnb.com/users/show/114503989
# 4625    2912333    https://www.airbnb.com/users/show/2912333
# 4626   50413447   https://www.airbnb.com/users/show/50413447
#
#                   name host_since                          location  \
# 0              Rebecca    8/29/08  Chicago, Illinois, United States
# 1     Craig & Kathleen   12/29/08  Chicago, Illinois, United States
# 2                Sarah    5/19/09  Chicago, Illinois, United States
# 3          At Home Inn    8/21/09  Chicago, Illinois, United States
# 4                 Lois    8/16/08   Aurora, Illinois, United States
# ...                ...        ...                               ...
# 4622             Terri    8/12/19  Chicago, Illinois, United States
# 4623             Brian   12/10/15  Chicago, Illinois, United States
# 4624            Jesson     2/2/17                             China
# 4625          Benjamin    7/12/12  Chicago, Illinois, United States
# 4626         Christian    12/2/15  Chicago, Illinois, United States
#
#            response_time superhost
# 0         within an hour         t
# 1     within a few hours         t
# 2         within an hour         t
# 3         within an hour         f
# 4         within an hour         f
# ...                  ...       ...
# 4622                 NaN         f
# 4623                 NaN         f
# 4624                 NaN         f
# 4625                 NaN         f
# 4626      within an hour         t
#
# [4627 rows x 7 columns]

# %%
host.isna().sum()
# Out:
# id                 0
# host_url           0
# name               0
# host_since         0
# location          10
# response_time    767
# superhost          0
# dtype: int64

# %%
lst
# Out:
#             id                            listing_url  \
# 0         2384      https://www.airbnb.com/rooms/2384
# 1         4505      https://www.airbnb.com/rooms/4505
# 2         7126      https://www.airbnb.com/rooms/7126
# 3         9811      https://www.airbnb.com/rooms/9811
# 4        10610     https://www.airbnb.com/rooms/10610
# ...        ...                                    ...
# 8528  40262251  https://www.airbnb.com/rooms/40262251
# 8529  40263536  https://www.airbnb.com/rooms/40263536
# 8530  40264107  https://www.airbnb.com/rooms/40264107
# 8531  40264148  https://www.airbnb.com/rooms/40264148
# 8532  40264411  https://www.airbnb.com/rooms/40264411
#
#                                                    name  \
# 0     Walk to UChicago, 10 min train to McCormick Place
# 1     One Great Apartment. 384 Great Reviews. 1 Bad ...
# 2                   Tiny Studio Apartment 94 Walk Score
# 3                         Barbara's Hideaway - Old Town
# 4                      3 Comforts of Cooperative Living
# ...                                                 ...
# 8528  Perfect Old Town condo you will love. Come stay!!
# 8529  ☼O'Hare-1Bed-Private Bath-Rosemont-AllState Arena
# 8530    One queen bed room in cozy house northwest side
# 8531  ☼2bed 1bath O'hare, Allstate arena,Casino,Rose...
# 8532      Modern Private Room/ quick walk to the train!
#
#                                             description    host_id host_since  \
# 0     Visiting The University of Chicago or attendin...       2613    8/29/08
# 1     We took the winter off, made things nicer arou...       5775   12/29/08
# 2     A very small studio in a wonderful neighborhoo...      17928    5/19/09
# 3     One-bedroom hideaway tucked into Old Town step...      33004    8/21/09
# 4     The condo is the 2nd floor in a lovely 1912 3-...       2140    8/16/08
# ...                                                 ...        ...        ...
# 8528  This is a beautiful million-dollar condo, perf...    2912333    7/12/12
# 8529  Is this your first booking on Airbnb? Use this...   50413447    12/2/15
# 8530  Nice and quiet neighborhood, save a bunch agai...   35065108     6/5/15
# 8531  Is this your first booking on Airbnb? Use this...   50413447    12/2/15
# 8532  Enjoy a clean & comfortable room in a 1bd 2.5b...  178275885    3/13/18
#
#           neighbourhood         city state zipcode  ... cleaning_fee  \
# 0             Hyde Park      Chicago    IL   60637  ...        $0.00
# 1        Little Village      Chicago    IL   60608  ...       $25.00
# 2     Ukrainian Village      Chicago    IL   60622  ...        $0.00
# 3              Old Town      Chicago    IL   60614  ...       $95.00
# 4             Hyde Park      Chicago    IL   60615  ...       $50.00
# ...                 ...          ...   ...     ...  ...          ...
# 8528                NaN      Chicago    IL   60610  ...          NaN
# 8529                NaN  Des Plaines    IL   60018  ...          NaN
# 8530                NaN      Chicago    IL   60634  ...       $12.00
# 8531                NaN  Des Plaines    IL   60018  ...        $0.00
# 8532                NaN      Chicago    IL   60608  ...       $10.00
#
#       review_scores_rating  review_scores_accuracy review_scores_cleanliness  \
# 0                    100.0                    10.0                      10.0
# 1                     96.0                    10.0                       9.0
# 2                     93.0                    10.0                       9.0
# 3                     92.0                    10.0                       9.0
# 4                     82.0                     8.0                       7.0
# ...                    ...                     ...                       ...
# 8528                   NaN                     NaN                       NaN
# 8529                   NaN                     NaN                       NaN
# 8530                   NaN                     NaN                       NaN
# 8531                   NaN                     NaN                       NaN
# 8532                   NaN                     NaN                       NaN
#
#      review_scores_checkin  review_scores_communication  \
# 0                     10.0                         10.0
# 1                     10.0                         10.0
# 2                     10.0                         10.0
# 3                     10.0                          9.0
# 4                      9.0                          9.0
# ...                    ...                          ...
# 8528                   NaN                          NaN
# 8529                   NaN                          NaN
# 8530                   NaN                          NaN
# 8531                   NaN                          NaN
# 8532                   NaN                          NaN
#
#       review_scores_location  review_scores_value instant_bookable  \
# 0                       10.0                 10.0                f
# 1                        9.0                  9.0                t
# 2                       10.0                 10.0                f
# 3                       10.0                  9.0                t
# 4                       10.0                  9.0                t
# ...                      ...                  ...              ...
# 8528                     NaN                  NaN                t
# 8529                     NaN                  NaN                t
# 8530                     NaN                  NaN                t
# 8531                     NaN                  NaN                t
# 8532                     NaN                  NaN                f
#
#               cancellation_policy
# 0     strict_14_with_grace_period
# 1                        moderate
# 2                        moderate
# 3     strict_14_with_grace_period
# 4                        moderate
# ...                           ...
# 8528                     flexible
# 8529                     flexible
# 8530                     flexible
# 8531                     moderate
# 8532                     flexible
#
# [8533 rows x 29 columns]

# %%
type(lst)
# Out:
# pandas.core.frame.DataFrame

# %%
lst.isna().sum()
# Out:
# id                                0
# listing_url                       0
# name                              0
# description                     129
# host_id                           0
# host_since                        0
# neighbourhood                    27
# city                              3
# state                            23
# zipcode                          22
# country_code                      0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         3
# bedrooms                          4
# security_deposit               2086
# cleaning_fee                    836
# review_scores_rating           1244
# review_scores_accuracy         1244
# review_scores_cleanliness      1244
# review_scores_checkin          1245
# review_scores_communication    1246
# review_scores_location         1245
# review_scores_value            1245
# instant_bookable                  0
# cancellation_policy               0
# dtype: int64

# %%
lst.dtypes
# Out:
# id                               int64
# listing_url                     object
# name                            object
# description                     object
# host_id                          int64
# host_since                      object
# neighbourhood                   object
# city                            object
# state                           object
# zipcode                         object
# country_code                    object
# latitude                       float64
# longitude                      float64
# property_type                   object
# room_type                       object
# accommodates                     int64
# bathrooms                      float64
# bedrooms                       float64
# security_deposit                object
# cleaning_fee                    object
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# instant_bookable                object
# cancellation_policy             object
# dtype: object

# %%
rev.iloc[]
# Out:
# id                                                       217997495
# listing_id                                                21784716
# date                                                      12/10/17
# reviewer_id                                               46340737
# reviewer_name                                                  Zac
# comments         Awesome place, great neighborhood. It's right ...
# Name: 233903, dtype: object

# %%
rev.isna().sum()
# Out:
# id                 0
# listing_id         0
# date               0
# reviewer_id        0
# reviewer_name      0
# comments         251
# dtype: int64
